# %%
print("Kel : My Little Bolu Ketan")
print("Kelas : IF-48-06")
print("Judul : Penerapan Sistem Inferensi Fuzzy Sugeno an Mamdani untuk Mengestimasi Harga Jual")
print("        Mobil Bekas Toyota Berdasarkan Karakteristik Spesifikasi Kendaraan ")
# Out:
# Kel : My Little Bolu Ketan
# Kelas : IF-48-06
# Judul : Penerapan Sistem Inferensi Fuzzy Sugeno an Mamdani untuk Mengestimasi Harga Jual
#         Mobil Bekas Toyota Berdasarkan Karakteristik Spesifikasi Kendaraan

# %%
import pandas as pd

# Membaca dataset
df = pd.read_csv('toyota.csv')

# Menampilkan statistik dasar untuk mencari batas Fuzzifikasi
df[['year', 'mileage', 'tax', 'mpg', 'engineSize']].describe()
# Out:
#               year        mileage          tax          mpg   engineSize
# count  6738.000000    6738.000000  6738.000000  6738.000000  6738.000000
# mean   2016.748145   22857.413921    94.697240    63.042223     1.471297
# std       2.204062   19125.464147    73.880776    15.836710     0.436159
# min    1998.000000       2.000000     0.000000     2.800000     0.000000
# 25%    2016.000000    9446.000000     0.000000    55.400000     1.000000
# 50%    2017.000000   18513.000000   135.000000    62.800000     1.500000
# 75%    2018.000000   31063.750000   145.000000    69.000000     1.800000
# max    2020.000000  174419.000000   565.000000   235.000000     4.500000
